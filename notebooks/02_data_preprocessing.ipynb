# %% [markdown]
# # Подготовка данных / Feature Engineering

# %% [markdown]
# ## Обработка выбросов, масштабирование числовых признаков, кодирование категориальных (если появятся)

# %% [markdown]
# Здесь мы будем:
#
# - Оставлять предобработку данных посе того как попробуем все на baseline моделях;
# - Создадим пайплайн предобработки двнный;
# -

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('../data/raw/train.csv')
test = pd.read_csv('../data/raw/test.csv')

# %% [markdown]
# ## Создание новых признаков, отбор признаков
